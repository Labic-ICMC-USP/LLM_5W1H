# %%
# Installs required OpenAI's python library
# %pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openai
#   Downloading openai-1.100.2-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/lvcas/.local/lib/python3.10/site-packages (from openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/lvcas/.local/lib/python3.10/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/lvcas/.local/lib/python3.10/site-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in /home/lvcas/.local/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/lvcas/.local/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/lvcas/.local/lib/python3.10/site-packages (from openai) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/lvcas/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /home/lvcas/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /home/lvcas/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/lvcas/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/lvcas/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lvcas/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/lvcas/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Downloading openai-1.100.2-py3-none-any.whl (787 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787.8/787.8 kB 2.6 MB/s  0:00:0036m-:--:--
# Downloading jiter-0.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (352 kB)
# Installing collected packages: jiter, openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openai]2m1/2 [openai]
# Successfully installed jiter-0.10.0 openai-1.100.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from llm5w1h import NewsArticle, LLMConnector, NewsAnalyzer

# %%
llm_endpoint = # your LLM endpoint
api_key = "api_key" # your LLM key
model = "llama3.1" # name of used LLM model

# %%
analyzer = NewsAnalyzer(llm_endpoint, api_key, model)

# %% [markdown]
# # Example in English

# %%
title = "Taliban attacks German consulate in northern Afghan city of Mazar-i-Sharif with truck bomb"
description = "The death toll from a powerful Taliban truck bombing at the German consulate in Afghanistan's Mazar-i-Sharif city rose to at least six Friday, with more than 100 others wounded in a major militant assault."
text = "The death toll from a powerful Taliban truck bombing at the German consulate in Afghanistan's Mazar-i-Sharif city rose to at least six Friday, with more than 100 others wounded in a major militant assault. The Taliban said the bombing late Thursday, which tore a massive crater in the road and overturned cars, was a \"revenge attack\" for US air strikes this month in the volatile province of Kunduz that left 32 civilians dead. The explosion, followed by sporadic gunfire, reverberated across the usually tranquil northern city, smashing windows of nearby shops and leaving terrified local residents fleeing for cover. \"The suicide attacker rammed his explosives-laden car into the wall of the German consulate,\" local police chief Sayed Kamal Sadat told AFP. All German staff from the consulate were unharmed, according to the foreign ministry in Berlin."
date = "2016-11-11 08:42:13"
url = "http://www.telegraph.co.uk/news/2016/11/10/taliban-attack-german-consulate-in-northern-afghan-city-of-mazar/"
en_example = NewsArticle(title, description, text, date, url)

# %%
analyzer.process_article(en_example)
# Out:
# Date: 2016-11-11 08:42:13
# Title: Taliban attacks German consulate in northern Afghan city of Mazar-i-Sharif with truck bomb
# Description: The death toll from a powerful Taliban truck bombing at the German consulate in Afghanistan's Mazar-i-Sharif city rose to at least six Friday, with more than 100 others wounded in a major militant assault.
# Text: The death toll from a powerful Taliban truck bombing at the German consulate in Afghanistan's Mazar-i-Sharif city rose to at least six Friday, with more than 100 others wounded in a major militant assault. The Taliban said the bombing late Thursday, which tore a massive crater in the road and overturned cars, was a "revenge attack" for US air strikes this month in the volatile province of Kunduz that left 32 civilians dead. The explosion, followed by sporadic gunfire, reverberated across the usually tranquil northern city, smashing windows of nearby shops and leaving terrified local residents fleeing for cover. "The suicide attacker rammed his explosives-laden car into the wall of the German consulate," local police chief Sayed Kamal Sadat told AFP. All German staff from the consulate were unharmed, according to the foreign ministry in Berlin.
# URL: http://www.telegraph.co.uk/news/2016/11/10/taliban-attack-german-consulate-in-northern-afghan-city-of-mazar/
# {'Who': 'Taliban',
#  'What': 'Truck bombing at the German consulate in Mazar-i-Sharif city, Afghanistan',
#  'When': 'Thursday (late) and Friday (at least six deaths reported)',
#  'Where': 'Mazar-i-Sharif city, northern Afghanistan',
#  'Why': 'Revenge attack for US air strikes in Kunduz province that left 32 civilians dead',
#  'How': 'A suicide attacker rammed his explosives-laden car into the wall of the German consulate'}

# %%
analyzer.identify_component('What')
# Out:
# 'Truck bombing at the German consulate in Mazar-i-Sharif city, Afghanistan'

# %% [markdown]
# # Example in portuguese

# %%
title = "Brasil pode ter recorde de casos de dengue em 2024, diz Ministério da Saúde"
description = "Vacinação começou nesta sexta (9) pelas crianças de 10 a 11 anos e irá avançar a faixa etária conforme novos lotes forem entregues pelo fabricante"
text = '''Brasil pode ter recorde de casos de dengue em 2024, diz Ministério da Saúde

Vacinação começou nesta sexta (9) pelas crianças de 10 a 11 anos e irá avançar a faixa etária conforme novos lotes forem entregues pelo fabricante.

O Ministério da Saúde divulgou nesta sexta-feira (9) uma projeção de que o Brasil pode chegar a 4,2 milhões de casos de dengue em 2024. A secretária de Vigilância em Saúde do Ministério da Saúde, Ethel Maciel, afirmou que a pasta se prepara para o pior cenário, que marcaria um recorde de casos da doença no país, mas que o trabalho vem sendo feito para evitar que essa situação aconteça.

“A estimativa do Ministério da Saúde é que a gente chegue a 4,2 milhões de casos [em 2024]. Nós nunca chegamos a esse número, por isso a preocupação. Nós também tememos pela pressão que isso pode acontecer no serviço de saúde. Por isso nós estamos nos preparando desde o ano passado”, afirmou a secretária.

A distribuição das doses da vacina Qdenga, da farmacêutica japonesa Takeda, para uma primeira parte dos 521 municípios selecionados pela campanha de imunização contra a doença no Sistema Único de Saúde (SUS) começou na quinta-feira (8), e a vacinação nesta sexta.

O lote inicial de vacinas, com 712 mil doses, será enviado aos seguintes estados, contemplando 315 municípios: DF, GO, BA, AC, PB, RN, MS, AM, SP e MA.
'''
date = "09/02/2024"
url = "https://www.cnnbrasil.com.br/nacional/brasil-pode-ter-recorde-de-casos-de-dengue-em-2024-diz-ministerio-da-saude/"
pt_example = NewsArticle(title, description, text, date, url)

# %%
analyzer.process_article(pt_example)
# Out:
# Date: 09/02/2024
# Title: Brasil pode ter recorde de casos de dengue em 2024, diz Ministério da Saúde
# Description: Vacinação começou nesta sexta (9) pelas crianças de 10 a 11 anos e irá avançar a faixa etária conforme novos lotes forem entregues pelo fabricante
# Text: Brasil pode ter recorde de casos de dengue em 2024, diz Ministério da Saúde
#
# Vacinação começou nesta sexta (9) pelas crianças de 10 a 11 anos e irá avançar a faixa etária conforme novos lotes forem entregues pelo fabricante.
#
# O Ministério da Saúde divulgou nesta sexta-feira (9) uma projeção de que o Brasil pode chegar a 4,2 milhões de casos de dengue em 2024. A secretária de Vigilância em Saúde do Ministério da Saúde, Ethel Maciel, afirmou que a pasta se prepara para o pior cenário, que marcaria um recorde de casos da doença no país, mas que o trabalho vem sendo feito para evitar que essa situação aconteça.
#
# “A estimativa do Ministério da Saúde é que a gente chegue a 4,2 milhões de casos [em 2024]. Nós nunca chegamos a esse número, por isso a preocupação. Nós também tememos pela pressão que isso pode acontecer no serviço de saúde. Por isso nós estamos nos preparando desde o ano passado”, afirmou a secretária.
#
# A distribuição das doses da vacina Qdenga, da farmacêutica japonesa Takeda, para uma primeira parte dos 521 municípios selecionados pela campanha de imunização contra a doença no Sistema Único de Saúde (SUS) começou na quinta-feira (8), e a vacinação nesta sexta.
#
# O lote inicial de vacinas, com 712 mil doses, será enviado aos seguintes estados, contemplando 315 municípios: DF, GO, BA, AC, PB, RN, MS, AM, SP e MA.
#
# URL: https://www.cnnbrasil.com.br/nacional/brasil-pode-ter-recorde-de-casos-de-dengue-em-2024-diz-ministerio-da-saude/
# {'Who': 'Ministério da Saúde, secretária de Vigilância em Saúde Ethel Maciel',
#  'What': 'Projeção de recorde de casos de dengue no Brasil em 2024',
#  'When': '2024 (projection for the year)',
#  'Where': 'Brasil',
#  'Why': 'Not mentioned',
#  'How': 'Due to an increase in cases, the Ministry of Health is preparing for the worst scenario and has started vaccinating children aged 10-11 years old'}

# %%
analyzer.identify_component('When')
# Out:
# '2024 (projection for the year)'
