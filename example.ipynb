# %%
# Installs required OpenAI's python library
# %pip install openai
# Out:
# Requirement already satisfied: openai in d:\python\python312\lib\site-packages (1.35.10)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\python\python312\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\python\python312\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\python\python312\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\python\python312\lib\site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in d:\python\python312\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\python\python312\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in d:\python\python312\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in d:\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in d:\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in d:\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in d:\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: colorama in d:\python\python312\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from src.NewsAnalyzerAPI import NewsArticle
from src.NewsAnalyzerAPI import LLMConnector
from src.NewsAnalyzerAPI import NewsAnalyzer

# %%
connector = LLMConnector("http://localhost:1234/v1")
analyzer = NewsAnalyzer(connector)

# %% [markdown]
# # Example in English

# %%
title = "Taliban attacks German consulate in northern Afghan city of Mazar-i-Sharif with truck bomb"
description = "The death toll from a powerful Taliban truck bombing at the German consulate in Afghanistan's Mazar-i-Sharif city rose to at least six Friday, with more than 100 others wounded in a major militant assault."
text = "The death toll from a powerful Taliban truck bombing at the German consulate in Afghanistan's Mazar-i-Sharif city rose to at least six Friday, with more than 100 others wounded in a major militant assault. The Taliban said the bombing late Thursday, which tore a massive crater in the road and overturned cars, was a \"revenge attack\" for US air strikes this month in the volatile province of Kunduz that left 32 civilians dead. The explosion, followed by sporadic gunfire, reverberated across the usually tranquil northern city, smashing windows of nearby shops and leaving terrified local residents fleeing for cover. \"The suicide attacker rammed his explosives-laden car into the wall of the German consulate,\" local police chief Sayed Kamal Sadat told AFP. All German staff from the consulate were unharmed, according to the foreign ministry in Berlin."
date = "2016-11-11 08:42:13"
url = "http://www.telegraph.co.uk/news/2016/11/10/taliban-attack-german-consulate-in-northern-afghan-city-of-mazar/"
en_example = NewsArticle(title, description, text, date, url)

# %%
analyzer.process_article(en_example)
# Out:
# what
# Sure, here's a summary of the key events that occur in the text:
#
# 1. A powerful Taliban truck bombing at the German consulate in Afghanistan's Mazar-i-Sharif city resulted in a death toll of at least six on Friday.
#
#
# 2. More than 100 others were wounded in the attack.
#
#
# 3. The Taliban claimed the bombing was a revenge attack for US air strikes in the volatile province of Kunduz.
#
#
# 4. The explosion, followed by sporadic gunfire, shattered windows of nearby shops and left terrified local residents fleeing for cover.
#
#
# 5. Local police chief Sayed Kamal Sadat confirmed that all German staff were unharmed.
# --------------
#
#
# where
# Afghanistan, Mazar-i-Sharif city.
#
# 1. German Consulate
# 2. Kunduz Province
# --------------
#
#
# when
# The events occurred on [2023-04-27].
#
# 1. A powerful Taliban truck bombing at the German consulate in Afghanistan's Mazar-i-Sharif city rose to at least six Friday.
#
#
# 2. More than 100 others wounded in a major militant assault.
# --------------
#
#
# who
# **People:**
#
# 1. Taliban
# 2. US military personnel
# 3. Local police chief Sayed Kamal Sadat
#
# **Organizations:**
#
# 1. German consulate in Afghanistan's Mazar-i-Sharif city
# --------------
#
#
# why
# The events described in the texts occurred due to a powerful Taliban truck bombing at the German consulate in Afghanistan's Mazar-i-Sharif city.
#
# 1. The Taliban said the bombing late Thursday, which tore a massive crater in the road and overturned cars, was a "revenge attack" for US air strikes this month in the volatile province of Kunduz that left 32 civilians dead.
#
#
# 2. The explosion, followed by sporadic gunfire, reverberated across the usually tranquil northern city, smashing windows of nearby shops and leaving terrified local residents fleeing for cover.
# --------------
#
#
# how
# Sure, here is a summary of the events described in the texts:
#
# 1. A powerful Taliban truck bombing occurred at the German consulate in Afghanistan's Mazar-i-Sharif city.
#
#
# 2. The bombing caused a massive crater in the road and overturned cars, resulting in significant damage and injuries.
#
#
# 3. The Taliban claimed it was a "revenge attack" for US air strikes this month in the volatile province of Kunduz that left 32 civilians dead.
#
#
# 4. Following the explosion, sporadic gunfire erupted, leaving terrified local residents fleeing for cover.
#
#
# 5. The attack on the German consulate resulted in the death toll of at least six individuals, with over 100 others wounded.
# --------------

# %%
analyzer.identify_component(en_example, 'what')
# Out:
# 'Sure, here\'s a list of events that occur in the text:\n\n1. A powerful Taliban truck bombing at the German consulate in Afghanistan\'s Mazar-i-Sharif city.\n\n\n2. More than 100 people are wounded in the attack.\n\n\n3. The Taliban said the bombing was a "revenge attack" for US air strikes this month in the volatile province of Kunduz that left 32 civilians dead.\n\n\n4. An explosion, followed by sporadic gunfire, reverberated across the usually tranquil northern city.\n\n\n5. Windows of nearby shops were smashed.\n\n\n6. Local residents fled for cover.'

# %% [markdown]
# # Example in portuguese

# %%
title = "Brasil pode ter recorde de casos de dengue em 2024, diz Ministério da Saúde"
description = "Vacinação começou nesta sexta (9) pelas crianças de 10 a 11 anos e irá avançar a faixa etária conforme novos lotes forem entregues pelo fabricante"
text = '''Brasil pode ter recorde de casos de dengue em 2024, diz Ministério da Saúde

Vacinação começou nesta sexta (9) pelas crianças de 10 a 11 anos e irá avançar a faixa etária conforme novos lotes forem entregues pelo fabricante.

O Ministério da Saúde divulgou nesta sexta-feira (9) uma projeção de que o Brasil pode chegar a 4,2 milhões de casos de dengue em 2024. A secretária de Vigilância em Saúde do Ministério da Saúde, Ethel Maciel, afirmou que a pasta se prepara para o pior cenário, que marcaria um recorde de casos da doença no país, mas que o trabalho vem sendo feito para evitar que essa situação aconteça.

“A estimativa do Ministério da Saúde é que a gente chegue a 4,2 milhões de casos [em 2024]. Nós nunca chegamos a esse número, por isso a preocupação. Nós também tememos pela pressão que isso pode acontecer no serviço de saúde. Por isso nós estamos nos preparando desde o ano passado”, afirmou a secretária.

A distribuição das doses da vacina Qdenga, da farmacêutica japonesa Takeda, para uma primeira parte dos 521 municípios selecionados pela campanha de imunização contra a doença no Sistema Único de Saúde (SUS) começou na quinta-feira (8), e a vacinação nesta sexta.

O lote inicial de vacinas, com 712 mil doses, será enviado aos seguintes estados, contemplando 315 municípios: DF, GO, BA, AC, PB, RN, MS, AM, SP e MA.
'''
date = "09/02/2024"
url = "https://www.cnnbrasil.com.br/nacional/brasil-pode-ter-recorde-de-casos-de-dengue-em-2024-diz-ministerio-da-saude/"
pt_example = NewsArticle(title, description, text, date, url)

# %%
analyzer.process_article(pt_example)
# Out:
# what
# Sure. Here is a summary of the events that occur in the text:
#
# **Timeline:**
#
# - 6th (9): Vaccination starts for children aged 10-11 years.
# - 9th (9): Projection released by the Ministry of Health predicting 4.2 million dengue cases in 2024.
# - 5th (8): Distribution of the Qdenga vaccine starts for a selected group of 521 municipalities.
#
# **Other events:**
#
# - The Ministry of Health is preparing for a record number of dengue cases.
# - A secretaria of the Ministry of Health warns that the situation could lead to a record number of cases.
# --------------
#
#
# where
# The context does not provide any information about the locations and places where the events described in the text occurred, so I cannot generate the requested output.
# --------------
#
#
# when
# Sure, here's the information you requested:
#
# * 2024-06-09: Vacinação começou nesta sexta (9) pelas crianças de 10 a 11 anos.
#
#
# * 2024-06-09: Projeção de que o Brasil pode chegar a 4,2 milhões de casos de dengue em 2024.
#
#
# * 2024-06-08: Distribuição das doses da vacina Qdenga para uma primeira parte dos 521 municípios selecionados pela campanha de imunização contra a doença no Sistema Único de Saúde (SUS).
# --------------
#
#
# who
# Sure. Here's the list of people and organizations:
#
# **People:**
#
# 1. Ministerio da Saúde do Brasil
# 2. Ethel Maciel, Secretária de Vigilância em Saúde do Ministério da Saúde
# 3. Anonymous
# 4. Doctors and health professionals
#
# **Organizations:**
#
# 1. Brazilian Ministry of Health
# 2. Takeda Pharmaceuticals
# --------------
#
#
# why
# Sure, here is a summary of the events described in the texts:
#
# **Reasons for the increase in dengue cases:**
#
# * The text doesn't specify specific reasons for the increase in cases, so I can't extract the requested information from the context.
#
#
# **Other details:**
#
# * Vaccination began on the sixth (9) and will continue to advance based on the arrival of new shipments of vaccines.
# * The Ministry of Health released a projection for 2024 that suggests the country could potentially reach up to 4,2 million dengue cases.
# * The secretária de Vigilância em Saúde, Ethel Maciel, expressed concern about the potential impact on the health service and emphasized the need to prepare for this situation.
# * The distribution of the Qdenga vaccine started in the fifth (8) and will be distributed to 521 selected municipalities.
# --------------
#
#
# how
# Sure, here's a summary of the events described in the text:
#
# **Vaccination:**
#
# * Vacinação started on the sixth (9) for children aged 10-11 years.
# * The vaccination will expand to other age groups as new batches are delivered by the manufacturer.
#
# **Projected Cases:**
#
# * The Ministry of Health predicts that Brazil could reach 4.2 million dengue cases in 2024.
#
# **Prevention Measures:**
#
# * The health secretary, Ethel Maciel, warns that this could be a record year for dengue cases in the country.
# * They are taking measures to avoid this, including preparing for the worst scenario.
#
# **Distribution of Dengue Vaccine:**
#
# * The distribution of the Qdenga vaccine began on the fifth (8) for 521 selected municipalities, with 712,000 doses being distributed.
# * The first batch will be sent to the following states: DF, GO, BA, AC, PB, RN, MS, AM, SP, and MA.
# --------------

# %%
analyzer.identify_component(pt_example, 'when')
# Out:
# 'Sure, here is the information about the dates of the events described in the text:\n\n- 2024 - Brasil pode ter recorde de casos de dengue.\n\n\n- 9th - Vacinação começou nesta sexta (9) pelas crianças de 10 a 11 anos.\n\n\n- 8th - Distribução das doses da vacina Qdenga, da farmacêutica japonesa Takeda, para uma primeira parte dos 521 municípios selecionados pela campanha de imunização contra a doença no Sistema Único de Saúde (SUS) começou.\n\n\n- 9th - Vacinação nesta sexta.'
