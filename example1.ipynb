# %%
# %pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.35.10-py3-none-any.whl.metadata (21 kB)
# Collecting anyio<5,>=3.5.0 (from openai)
#   Downloading anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ---------------------------------------- 0.0/125.2 kB ? eta -:--:--
#      ---------------------------------- --- 112.6/125.2 kB 3.3 MB/s eta 0:00:01
#      -------------------------------------- 125.2/125.2 kB 1.9 MB/s eta 0:00:00
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>4 in d:\python\python312\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in d:\python\python312\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in d:\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in d:\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.20.1-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: colorama in d:\python\python312\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.35.10-py3-none-any.whl (328 kB)
#    ---------------------------------------- 0.0/328.3 kB ? eta -:--:--
#    --------------------------------------  327.7/328.3 kB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 328.3/328.3 kB 5.1 MB/s eta 0:00:00
# Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#    ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/86.8 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 86.8/86.8 kB 1.2 MB/s eta 0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB 2.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ---------------------------------------- 77.9/77.9 kB 4.2 MB/s eta 0:00:00
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#    ---------------------------------------- 0.0/423.9 kB ? eta -:--:--
#    --------------------------------------  419.8/423.9 kB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 423.9/423.9 kB 6.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.20.1-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/1.9 MB 15.2 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.9 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.9 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 9.3 MB/s eta 0:00:00
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: sniffio, pydantic-core, h11, distro, annotated-types, pydantic, httpcore, anyio, httpx, openai
# Successfully installed annotated-types-0.7.0 anyio-4.4.0 distro-1.9.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.35.10 pydantic-2.8.2 pydantic-core-2.20.1 sniffio-1.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from src import NewsAnalyzerAPI as na

# %%
text = '''Brasil pode ter recorde de casos de dengue em 2024, diz Ministério da Saúde

Vacinação começou nesta sexta (9) pelas crianças de 10 a 11 anos e irá avançar a faixa etária conforme novos lotes forem entregues pelo fabricante.

O Ministério da Saúde divulgou nesta sexta-feira (9) uma projeção de que o Brasil pode chegar a 4,2 milhões de casos de dengue em 2024. A secretária de Vigilância em Saúde do Ministério da Saúde, Ethel Maciel, afirmou que a pasta se prepara para o pior cenário, que marcaria um recorde de casos da doença no país, mas que o trabalho vem sendo feito para evitar que essa situação aconteça.

“A estimativa do Ministério da Saúde é que a gente chegue a 4,2 milhões de casos [em 2024]. Nós nunca chegamos a esse número, por isso a preocupação. Nós também tememos pela pressão que isso pode acontecer no serviço de saúde. Por isso nós estamos nos preparando desde o ano passado”, afirmou a secretária.

A distribuição das doses da vacina Qdenga, da farmacêutica japonesa Takeda, para uma primeira parte dos 521 municípios selecionados pela campanha de imunização contra a doença no Sistema Único de Saúde (SUS) começou na quinta-feira (8), e a vacinação nesta sexta.

O lote inicial de vacinas, com 712 mil doses, será enviado aos seguintes estados, contemplando 315 municípios: DF, GO, BA, AC, PB, RN, MS, AM, SP e MA.
'''
article_example = na.NewsArticle("Brasil pode ter recorde de casos de dengue em 2024, diz Ministério da Saúde",
                              "Vacinação começou nesta sexta (9) pelas crianças de 10 a 11 anos e irá avançar a faixa etária conforme novos lotes forem entregues pelo fabricante",
                              text, "09/02/2024", "https://www.cnnbrasil.com.br/nacional/brasil-pode-ter-recorde-de-casos-de-dengue-em-2024-diz-ministerio-da-saude/")
news_list = []
news_list.append(article_example)

# %%
connector = na.LLMConnector("http://localhost:1234/v1")

# %%
analyzer = na.NewsAnalyzer(connector)
analyzer.process_articles(news_list)
# Out:
# Article title: Brasil pode ter recorde de casos de dengue em 2024, diz Ministério da Saúde
#
# what
# Sure, here's a list of events that occur in the text:
#
# 1. Vacinação começou nesta sexta (9) pelas crianças de 10 a 11 anos.
#
#
# 2. O Ministério da Saúde divulgou nesta sexta-feira (9) uma projeção de que o Brasil pode chegar a 4,2 milhões de casos de dengue em 2024.
#
#
# 3. A secretária de Vigilância em Saúde do Ministério da Saúde, Ethel Maciel, afirmou que a pasta se prepara para o pior cenário, que marcaria um recorde de casos da doença no país.
#
#
# 4. A distribuição das doses da vacina Qdenga, da farmacêutica japonesa Takeda, para uma primeira parte dos 521 municípios selecionados pela campanha de imunização contra a doença no Sistema Único de Saúde (SUS) começou na quinta-feira (8).
#
#
# 5. O lote inicial de vacinas, com 712 mil doses, será enviado aos seguintes estados: DF, GO, BA, AC, PB, RN, MS, AM, SP e MA.
# --------------
#
#
# where
# The events described in the text occurred in Brazil.
#
# - DF
# - GO
# - BA
# - AC
# - PB
# - RN
# - MS
# - AM
# - SP
# - MA
# --------------
#
#
# when
# 2024-06-09, 2024-06-08
#
#
# --------------
#
#
# who
# Sure, here's a list of the people and organizations described in the text:
#
# **People:**
# 1. Ministerio da Saúde do Brasil
# 2. Ethel Maciel, secretária de Vigilância em Saúde do Ministério da Saúde
#
#
# **Organizations:**
# 1. Sistema Único de Saúde (SUS)
# 2. Japanese Takeda pharmaceutical company
# --------------
#
#
# why
# The events described in the texts occurred as follows:
#
# - The Brazilian Ministry of Health has projected that the country could have up to 4.2 million cases of dengue in 2024.
#
#
# - Vaccination began on the sixth (9) for children aged 10 to 11 years and will advance to the age group as new batches are delivered by the manufacturer.
#
#
# - The Ministry of Health released a projection that the country could reach 4.2 million cases of dengue in 2024.
#
#
# - The Secretariat of Surveillance in Public Health at the Ministry of Health, Ethel Maciel, stated that the situation is worst-case scenario and that a record number of dengue cases would occur in the country. However, the work is being done to prevent this from happening.
#
#
# - The distribution of doses of the vaccine Qdenga began on the fifth (8) in 521 selected cities, with the first batch sent to the following states: DF, GO, BA, AC, PB, RN, MS, AM, SP and MA.
# --------------
#
#
# how
# Sure, here's a summary of the events described in the text:
#
# 1. The Brazilian Ministry of Health announced that there will be a record number of cases of dengue in 2024, with an estimated 4.2 million cases.
#
#
# 2. Vaccination began on Saturday (9) for children aged 10-11 years and will progress to the appropriate age group as new batches are delivered by the manufacturer.
#
#
# 3. The Ministry of Health released a projection indicating that Brazil could reach 4.2 million dengue cases in 2024.
#
#
# 4. The Director of the Brazilian Health Surveillance Secretariat, Ethel Maciel, stated that the worst-case scenario is approaching, marking a record number of dengue cases in the country, but that efforts are being made to prevent this from happening.
#
#
# 5. The distribution of doses for the Qdenga vaccine, a Japanese pharmaceutical, began on Friday (8) for the first 521 selected municipalities according to the immunization campaign for dengue in the Unified Health System (SUS).
#
#
# 6. The initial batch of vaccines, with 712,000 doses, will be distributed to the following states: DF, GO, BA, AC, PB, RN, MS, AM, SP and MA.
# --------------
